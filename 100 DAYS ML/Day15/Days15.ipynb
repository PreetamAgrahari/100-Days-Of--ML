# %%
# !pip install pandas 
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=588eefaa7b1735fb3dff172dbd5024ac&language=en-US&page=1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=588eefaa7b1735fb3dff172dbd5024ac&language=en-US&page=1')
#
# NameError: name 'requests' is not defined

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 response.json()
#
# NameError: name 'response' is not defined
